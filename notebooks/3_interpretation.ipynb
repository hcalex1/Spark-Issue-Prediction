# %% [markdown]
# # INTERPRETATION

# %%
import pandas as pd
import math
from statsmodels.miscmodels.ordinal_model import OrderedModel

# %% [markdown]
# ## Imports Data

# %%
FEATURES_PATH = "../data/output/features.csv"
Y_PATH = "../data/output/y.csv"

SPARK_3_0_PREVIEW_RELEASE  = pd.to_datetime("Oct 29, 2019") 
SPARK_3_0_PREVIEW2_RELEASE = pd.to_datetime("Dec 16, 2019") 
SPARK_3_0_RELEASE          = pd.to_datetime("Jun 05, 2020") 
SPARK_3_0_1_RELEASE        = pd.to_datetime("Aug 27, 2020")

# %%
features = pd.read_csv(FEATURES_PATH, index_col="File")
features.head()
# Out:
#                                                     LinesCount  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...         134
# common/sketch/src/test/scala/org/apache/spark/u...         152
# core/src/test/scala/org/apache/spark/Accumulato...         205
# core/src/test/scala/org/apache/spark/BarrierSta...         262
# core/src/test/scala/org/apache/spark/Checkpoint...         645
#
#                                                     LinesAvgLength  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...              34
# common/sketch/src/test/scala/org/apache/spark/u...              31
# core/src/test/scala/org/apache/spark/Accumulato...              33
# core/src/test/scala/org/apache/spark/BarrierSta...              35
# core/src/test/scala/org/apache/spark/Checkpoint...              41
#
#                                                     LineCodeProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...            0.634328
# common/sketch/src/test/scala/org/apache/spark/u...            0.657895
# core/src/test/scala/org/apache/spark/Accumulato...            0.702439
# core/src/test/scala/org/apache/spark/BarrierSta...            0.843511
# core/src/test/scala/org/apache/spark/Checkpoint...            0.784496
#
#                                                     LineBlankProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...             0.253731
# common/sketch/src/test/scala/org/apache/spark/u...             0.243421
# core/src/test/scala/org/apache/spark/Accumulato...             0.146341
# core/src/test/scala/org/apache/spark/BarrierSta...             0.087786
# core/src/test/scala/org/apache/spark/Checkpoint...             0.130233
#
#                                                     TypesCount  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...           1
# common/sketch/src/test/scala/org/apache/spark/u...           1
# core/src/test/scala/org/apache/spark/Accumulato...           3
# core/src/test/scala/org/apache/spark/BarrierSta...           1
# core/src/test/scala/org/apache/spark/Checkpoint...           7
#
#                                                     ClassProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...         1.000000
# common/sketch/src/test/scala/org/apache/spark/u...         1.000000
# core/src/test/scala/org/apache/spark/Accumulato...         0.666667
# core/src/test/scala/org/apache/spark/BarrierSta...         1.000000
# core/src/test/scala/org/apache/spark/Checkpoint...         0.714286
#
#                                                     TraitProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...         0.000000
# common/sketch/src/test/scala/org/apache/spark/u...         0.000000
# core/src/test/scala/org/apache/spark/Accumulato...         0.000000
# core/src/test/scala/org/apache/spark/BarrierSta...         0.000000
# core/src/test/scala/org/apache/spark/Checkpoint...         0.142857
#
#                                                     MaxChildren  MethodCount  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...            1            4
# common/sketch/src/test/scala/org/apache/spark/u...            1            4
# core/src/test/scala/org/apache/spark/Accumulato...            1           12
# core/src/test/scala/org/apache/spark/BarrierSta...            1            2
# core/src/test/scala/org/apache/spark/Checkpoint...            2           24
#
#                                                     PrivateMethodProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...                 0.250000
# common/sketch/src/test/scala/org/apache/spark/u...                 0.250000
# core/src/test/scala/org/apache/spark/Accumulato...                 0.000000
# core/src/test/scala/org/apache/spark/BarrierSta...                 1.000000
# core/src/test/scala/org/apache/spark/Checkpoint...                 0.166667
#
#                                                     ProtectedMethodProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...                   0.000000
# common/sketch/src/test/scala/org/apache/spark/u...                   0.000000
# core/src/test/scala/org/apache/spark/Accumulato...                   0.000000
# core/src/test/scala/org/apache/spark/BarrierSta...                   0.000000
# core/src/test/scala/org/apache/spark/Checkpoint...                   0.416667
#
#                                                     MethodOverrideProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...                  0.000000
# common/sketch/src/test/scala/org/apache/spark/u...                  0.000000
# core/src/test/scala/org/apache/spark/Accumulato...                  0.333333
# core/src/test/scala/org/apache/spark/BarrierSta...                  0.000000
# core/src/test/scala/org/apache/spark/Checkpoint...                  0.125000
#
#                                                     FinalMethodProportion  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...                    0.0
# common/sketch/src/test/scala/org/apache/spark/u...                    0.0
# core/src/test/scala/org/apache/spark/Accumulato...                    0.0
# core/src/test/scala/org/apache/spark/BarrierSta...                    0.0
# core/src/test/scala/org/apache/spark/Checkpoint...                    0.0
#
#                                                     VarLocalCount  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...              0
# common/sketch/src/test/scala/org/apache/spark/u...              0
# core/src/test/scala/org/apache/spark/Accumulato...              0
# core/src/test/scala/org/apache/spark/BarrierSta...              0
# core/src/test/scala/org/apache/spark/Checkpoint...              0
#
#                                                     VarFieldCount  \
# File
# common/sketch/src/test/scala/org/apache/spark/u...              0
# common/sketch/src/test/scala/org/apache/spark/u...              0
# core/src/test/scala/org/apache/spark/Accumulato...              3
# core/src/test/scala/org/apache/spark/BarrierSta...              0
# core/src/test/scala/org/apache/spark/Checkpoint...              1
#
#                                                     MagicNumbersCount
# File
# common/sketch/src/test/scala/org/apache/spark/u...                 17
# common/sketch/src/test/scala/org/apache/spark/u...                 14
# core/src/test/scala/org/apache/spark/Accumulato...                  3
# core/src/test/scala/org/apache/spark/BarrierSta...                 35
# core/src/test/scala/org/apache/spark/Checkpoint...                  8

# %%
y = pd.read_csv(Y_PATH, index_col="File")
y.head()
# Out:
#                                                     DTCreated
# File
# common/sketch/src/test/scala/org/apache/spark/u...          3
# common/sketch/src/test/scala/org/apache/spark/u...          3
# core/src/test/scala/org/apache/spark/Accumulato...          3
# core/src/test/scala/org/apache/spark/BarrierSta...          2
# core/src/test/scala/org/apache/spark/Checkpoint...          3

# %% [markdown]
# ## Training the model
# Lets train our model using the entire dataset and retrieve the estimated coefficients.

# %%
mod_log = OrderedModel(y, features, distr='logit')
res_log = mod_log.fit(method='bfgs')
summary_log = pd.DataFrame(res_log.summary(alpha=0.05).tables[1].data).set_index(0)
summary_log.columns = summary_log.iloc[0]
summary_log = summary_log.iloc[1:, :]
summary_log.index.name = None
summary_log = summary_log.applymap(lambda x : float(x))

summary_log
# Out:
# Optimization terminated successfully.
#          Current function value: 0.624511
#          Iterations: 102
#          Function evaluations: 110
#          Gradient evaluations: 110
#                              coef  std err      z  P>|z|  [0.025  0.975]
# LinesCount                -0.0017    0.000 -6.619  0.000  -0.002  -0.001
# LinesAvgLength            -0.0266    0.021 -1.245  0.213  -0.068   0.015
# LineCodeProportion        -4.6666    1.164 -4.010  0.000  -6.948  -2.385
# LineBlankProportion        2.1147    2.833  0.746  0.455  -3.438   7.668
# TypesCount                -0.0268    0.030 -0.883  0.377  -0.086   0.033
# ClassProportion            0.1088    0.345  0.316  0.752  -0.567   0.785
# TraitProportion           -0.1548    0.625 -0.247  0.805  -1.381   1.071
# MaxChildren               -0.0751    0.095 -0.787  0.431  -0.262   0.112
# MethodCount                0.0111    0.011  0.984  0.325  -0.011   0.033
# PrivateMethodProportion   -0.2115    0.283 -0.748  0.454  -0.766   0.342
# ProtectedMethodProportion -0.6542    0.427 -1.534  0.125  -1.490   0.182
# MethodOverrideProportion  -0.4097    0.297 -1.378  0.168  -0.993   0.173
# FinalMethodProportion     -0.2974    3.505 -0.085  0.932  -7.166   6.572
# VarLocalCount             -0.0341    0.030 -1.136  0.256  -0.093   0.025
# VarFieldCount              0.1089    0.040  2.699  0.007   0.030   0.188
# MagicNumbersCount          0.0016    0.002  0.942  0.346  -0.002   0.005
# 0/1                       -8.6326    1.382 -6.247  0.000 -11.341  -5.924
# 1/2                        0.6871    0.090  7.625  0.000   0.510   0.864
# 2/3                       -1.1795    0.159 -7.426  0.000  -1.491  -0.868

# %% [markdown]
# ## ANOVA

# %% [markdown]
# Let conduct an analysis of variance for our model.

# %%
summary_log["Wald chi-sqr"] = pd.NA
summary_log["Wald chi-sqr"].iloc[:-3] = summary_log.index[:-3].map(lambda index : res_log.wald_test(r_matrix="{} = 0".format(index)).statistic[0][0])

summary_log
# Out:
# /home/school/opt/miniconda3/envs/ds/lib/python3.10/site-packages/statsmodels/base/model.py:1889: FutureWarning: The behavior of wald_test will change after 0.14 to returning scalar test statistic values. To get the future behavior now, set scalar to True. To silence this message while retaining the legacy behavior, set scalar to False.
#   warnings.warn(
# /tmp/ipykernel_14949/2827432499.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   summary_log["Wald chi-sqr"].iloc[:-3] = summary_log.index[:-3].map(lambda index : res_log.wald_test(r_matrix="{} = 0".format(index)).statistic[0][0])
#                              coef  std err      z  P>|z|  [0.025  0.975]  \
# LinesCount                -0.0017    0.000 -6.619  0.000  -0.002  -0.001
# LinesAvgLength            -0.0266    0.021 -1.245  0.213  -0.068   0.015
# LineCodeProportion        -4.6666    1.164 -4.010  0.000  -6.948  -2.385
# LineBlankProportion        2.1147    2.833  0.746  0.455  -3.438   7.668
# TypesCount                -0.0268    0.030 -0.883  0.377  -0.086   0.033
# ClassProportion            0.1088    0.345  0.316  0.752  -0.567   0.785
# TraitProportion           -0.1548    0.625 -0.247  0.805  -1.381   1.071
# MaxChildren               -0.0751    0.095 -0.787  0.431  -0.262   0.112
# MethodCount                0.0111    0.011  0.984  0.325  -0.011   0.033
# PrivateMethodProportion   -0.2115    0.283 -0.748  0.454  -0.766   0.342
# ProtectedMethodProportion -0.6542    0.427 -1.534  0.125  -1.490   0.182
# MethodOverrideProportion  -0.4097    0.297 -1.378  0.168  -0.993   0.173
# FinalMethodProportion     -0.2974    3.505 -0.085  0.932  -7.166   6.572
# VarLocalCount             -0.0341    0.030 -1.136  0.256  -0.093   0.025
# VarFieldCount              0.1089    0.040  2.699  0.007   0.030   0.188
# MagicNumbersCount          0.0016    0.002  0.942  0.346  -0.002   0.005
# 0/1                       -8.6326    1.382 -6.247  0.000 -11.341  -5.924
# 1/2                        0.6871    0.090  7.625  0.000   0.510   0.864
# 2/3                       -1.1795    0.159 -7.426  0.000  -1.491  -0.868
#
#                           Wald chi-sqr
# LinesCount                   43.815074
# LinesAvgLength                1.548925
# LineCodeProportion           16.077091
# LineBlankProportion           0.557069
# TypesCount                    0.779362
# ClassProportion               0.099551
# TraitProportion               0.061225
# MaxChildren                   0.619438
# MethodCount                   0.967703
# PrivateMethodProportion       0.560053
# ProtectedMethodProportion     2.351808
# MethodOverrideProportion        1.8984
# FinalMethodProportion         0.007203
# VarLocalCount                 1.289404
# VarFieldCount                 7.284005
# MagicNumbersCount             0.886925
# 0/1                               <NA>
# 1/2                               <NA>
# 2/3                               <NA>

# %%
significant_features = ["LinesCount", "LineCodeProportion", "VarFieldCount", "ProtectedMethodProportion", "MethodOverrideProportion"]
features.corr().loc[significant_features, significant_features]
# Out:
#                            LinesCount  LineCodeProportion  VarFieldCount  \
# LinesCount                   1.000000            0.402058       0.334456
# LineCodeProportion           0.402058            1.000000       0.178948
# VarFieldCount                0.334456            0.178948       1.000000
# ProtectedMethodProportion   -0.037925           -0.060035      -0.076503
# MethodOverrideProportion    -0.109857           -0.205886       0.098190
#
#                            ProtectedMethodProportion  MethodOverrideProportion
# LinesCount                                 -0.037925                 -0.109857
# LineCodeProportion                         -0.060035                 -0.205886
# VarFieldCount                              -0.076503                  0.098190
# ProtectedMethodProportion                   1.000000                  0.157351
# MethodOverrideProportion                    0.157351                  1.000000
